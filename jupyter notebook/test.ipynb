# %%
from streamlit_autocomplete import st_autocomplete
# Out:
# 2025-10-06 22:55:35.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from streamlit_autocomplete import st_autocomplete
#
# ImportError: cannot import name 'st_autocomplete' from 'streamlit_autocomplete' (C:\Users\lotus\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit_autocomplete\__init__.py)

# %%
#!pip install streamlit-autocomplete

# %%
from streamlit_autocomplete import autocomplete
