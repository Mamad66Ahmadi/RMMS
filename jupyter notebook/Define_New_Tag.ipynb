# %%
import streamlit as st
import pandas as pd
from utils.top_bar import display_top_bar
from utils import sql_queries
from datetime import date
import os
from utils import tag_modification


# --- Helpers ---
def qp_first(key: str, default: str = "Unknown") -> str:
    """Get the first value of a query param."""
    val = st.query_params.get(key, default)
    if isinstance(val, list):
        return val[0] if val else default
    return val or default


# --- Main Function ---
def main():
    st.set_page_config(page_title="Tag Modification", layout="wide")

    username = qp_first("username", "Unknown")
    name = qp_first("name", "")
    department = qp_first("department", "")

    try:
        pc_user = os.getlogin()
    except Exception:
        pc_user = "Unknown-PC"

    if username == "Unknown" or not username.strip():
        st.warning("⚠️ You should log in first.")
        st.markdown(
            "<a href='/' style='font-size:16px; color:blue; text-decoration:underline;'>⬅️ Go to Log-in Page</a>",
            unsafe_allow_html=True
        )
        return

    display_top_bar(name, department)
    st.title("🏷️ Tag Management")

    # --- Editable Section ---
    with st.expander("✏️ Edit Equipment Info", expanded=False):
        selected_tag = tag_modification.search_tags_box()
    
        if selected_tag:
            st.success(f"Selected tag: {selected_tag}")
            # next step: load fields for editing


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 from utils.top_bar import display_top_bar
#
# ModuleNotFoundError: No module named 'streamlit'
