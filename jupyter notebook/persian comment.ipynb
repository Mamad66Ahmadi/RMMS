# %%
            # Persian-compatible comment box
            st.markdown(
                """
                <style>
                /* Apply Persian font and RTL to Streamlit textareas */
                .stTextArea textarea {
                    font-family: Tahoma, 'IRANSans', 'Vazir', sans-serif;
                    direction: rtl;
                    text-align: right;
                    line-height: 1.6;
                    font-size: 14px;
                }
                </style>
                """,
                unsafe_allow_html=True
            )
            
            new_comment = st.text_area(
                "نظر خود را وارد کنید",
                value="",
                height=150,
                placeholder="اینجا می‌توانید توضیحات خود را بنویسید...",
                key="new_comment"
            )
